# %%
import pandas as pd
import numpy as np

from datetime import datetime
import pickle

from utilities import fix_date

# %%
noaa_df = pickle.load( open( "weather_data.pkl", "rb" ) )

# %% [markdown]
# ### Fix the dates to match other dataframe

# %%
df, dates = fix_date(noaa_df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49814 entries, 0 to 60793
# Columns: 125 entries, index to WindEquipmentChangeDate
# dtypes: datetime64[ns](1), float64(67), int64(2), object(55)
# memory usage: 47.9+ MB

# %%
len(dates)
# Out:
# 49750

# %%
type(dates[10])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type(df.DATE.loc[100])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
len(df)
# Out:
# 49814

# %%
df.DATE
# Out:
# 0       2015-07-01 00:53:00
# 1       2015-07-01 01:53:00
# 2       2015-07-01 02:53:00
# 3       2015-07-01 03:53:00
# 4       2015-07-01 04:53:00
#                 ...
# 60789   2021-03-06 17:53:00
# 60790   2021-03-06 18:53:00
# 60791   2021-03-06 19:53:00
# 60792   2021-03-06 20:53:00
# 60793   2021-03-06 21:53:00
# Name: DATE, Length: 49814, dtype: datetime64[ns]

# %% [markdown]
# ### Test shortdate approach to identify days with more than 24 recordings

# %% [markdown]
# **Shortdate approach: slice date, count number of recordings per "shortdate," filter out those without exactly 24 recordings to identify dates with exactly one per hour**

# %%
str(df.DATE.loc[100])[:10]
# Out:
# '2015-07-05'

# %%
df['SHORTDATE'] = df.DATE.apply(lambda x: str(x)[:10])

# %%
df["RECORDING_COUNT"] = df.groupby("SHORTDATE")["SOURCE"].transform('count')

# %%
test_df = df[df.RECORDING_COUNT == 24]

# %%
test_df.shape
# Out:
# (47784, 127)

# %%
test_df.head()
# Out:
#    index      STATION                DATE REPORT_TYPE SOURCE  AWND  \
# 0      0  72793524234 2015-07-01 00:53:00       FM-15      7   NaN
# 1      1  72793524234 2015-07-01 01:53:00       FM-15      7   NaN
# 2      2  72793524234 2015-07-01 02:53:00       FM-15      7   NaN
# 3      3  72793524234 2015-07-01 03:53:00       FM-15      7   NaN
# 4      4  72793524234 2015-07-01 04:53:00       FM-15      7   NaN
#
#    BackupDirection  BackupDistance  BackupDistanceUnit  BackupElements  ...  \
# 0              NaN             NaN                 NaN             NaN  ...
# 1              NaN             NaN                 NaN             NaN  ...
# 2              NaN             NaN                 NaN             NaN  ...
# 3              NaN             NaN                 NaN             NaN  ...
# 4              NaN             NaN                 NaN             NaN  ...
#
#    ShortDurationPrecipitationValue100  ShortDurationPrecipitationValue120  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    ShortDurationPrecipitationValue150  ShortDurationPrecipitationValue180  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    Sunrise  Sunset  TStorms  WindEquipmentChangeDate   SHORTDATE  \
# 0      NaN     NaN      NaN               2007-05-17  2015-07-01
# 1      NaN     NaN      NaN               2007-05-17  2015-07-01
# 2      NaN     NaN      NaN               2007-05-17  2015-07-01
# 3      NaN     NaN      NaN               2007-05-17  2015-07-01
# 4      NaN     NaN      NaN               2007-05-17  2015-07-01
#
#    RECORDING_COUNT
# 0               24
# 1               24
# 2               24
# 3               24
# 4               24
#
# [5 rows x 127 columns]

# %% [markdown]
# ### electricity demand df: test shortdate approach to identify days with more than 24 recordings

# %%
e_df = pickle.load( open( "electricity_data.pkl", "rb" ) )

# %%
e_df.shape
# Out:
# (49720, 1)

# %%
e_df.head()
# Out:
#                            DEMAND
# DATE
# 2015-07-01 08:00:00+00:00   873.0
# 2015-07-01 09:00:00+00:00   833.0
# 2015-07-01 10:00:00+00:00   802.0
# 2015-07-01 11:00:00+00:00   796.0
# 2015-07-01 12:00:00+00:00   807.0

# %%
e_df.reset_index(inplace=True)

# %%
e_df['SHORTDATE'] = e_df.DATE.apply(lambda x: str(x)[:10])

# %%
e_df["RECORDING_COUNT"] = e_df.groupby("SHORTDATE")["DEMAND"].transform('count')

# %%
test_edf = e_df[e_df.RECORDING_COUNT == 24]

# %%
test_edf.shape
# Out:
# (49440, 4)

# %%
test_edf
# Out:
#                            DATE  DEMAND   SHORTDATE  RECORDING_COUNT
# 16    2015-07-02 00:00:00+00:00  1282.0  2015-07-02               24
# 17    2015-07-02 01:00:00+00:00  1277.0  2015-07-02               24
# 18    2015-07-02 02:00:00+00:00  1226.0  2015-07-02               24
# 19    2015-07-02 03:00:00+00:00  1186.0  2015-07-02               24
# 20    2015-07-02 04:00:00+00:00  1157.0  2015-07-02               24
# ...                         ...     ...         ...              ...
# 49703 2021-03-05 19:00:00+00:00  1276.0  2021-03-05               24
# 49704 2021-03-05 20:00:00+00:00  1291.0  2021-03-05               24
# 49705 2021-03-05 21:00:00+00:00  1279.0  2021-03-05               24
# 49706 2021-03-05 22:00:00+00:00  1246.0  2021-03-05               24
# 49707 2021-03-05 23:00:00+00:00  1208.0  2021-03-05               24
#
# [49440 rows x 4 columns]

# %% [markdown]
# ### More values in edf than wdf. Must match edf on unique shortdates from wdf

# %%
match = test_df.SHORTDATE.unique().tolist()

# %%
test_df.shape
# Out:
# (47784, 127)

# %%
test_df.head()
# Out:
#    index      STATION                DATE REPORT_TYPE SOURCE  AWND  \
# 0      0  72793524234 2015-07-01 00:53:00       FM-15      7   NaN
# 1      1  72793524234 2015-07-01 01:53:00       FM-15      7   NaN
# 2      2  72793524234 2015-07-01 02:53:00       FM-15      7   NaN
# 3      3  72793524234 2015-07-01 03:53:00       FM-15      7   NaN
# 4      4  72793524234 2015-07-01 04:53:00       FM-15      7   NaN
#
#    BackupDirection  BackupDistance  BackupDistanceUnit  BackupElements  ...  \
# 0              NaN             NaN                 NaN             NaN  ...
# 1              NaN             NaN                 NaN             NaN  ...
# 2              NaN             NaN                 NaN             NaN  ...
# 3              NaN             NaN                 NaN             NaN  ...
# 4              NaN             NaN                 NaN             NaN  ...
#
#    ShortDurationPrecipitationValue100  ShortDurationPrecipitationValue120  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    ShortDurationPrecipitationValue150  ShortDurationPrecipitationValue180  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    Sunrise  Sunset  TStorms  WindEquipmentChangeDate   SHORTDATE  \
# 0      NaN     NaN      NaN               2007-05-17  2015-07-01
# 1      NaN     NaN      NaN               2007-05-17  2015-07-01
# 2      NaN     NaN      NaN               2007-05-17  2015-07-01
# 3      NaN     NaN      NaN               2007-05-17  2015-07-01
# 4      NaN     NaN      NaN               2007-05-17  2015-07-01
#
#    RECORDING_COUNT
# 0               24
# 1               24
# 2               24
# 3               24
# 4               24
#
# [5 rows x 127 columns]

# %%
test_edf[test_edf.SHORTDATE.isin(match)]
# Out:
#                            DATE  DEMAND   SHORTDATE  RECORDING_COUNT
# 16    2015-07-02 00:00:00+00:00  1282.0  2015-07-02               24
# 17    2015-07-02 01:00:00+00:00  1277.0  2015-07-02               24
# 18    2015-07-02 02:00:00+00:00  1226.0  2015-07-02               24
# 19    2015-07-02 03:00:00+00:00  1186.0  2015-07-02               24
# 20    2015-07-02 04:00:00+00:00  1157.0  2015-07-02               24
# ...                         ...     ...         ...              ...
# 49703 2021-03-05 19:00:00+00:00  1276.0  2021-03-05               24
# 49704 2021-03-05 20:00:00+00:00  1291.0  2021-03-05               24
# 49705 2021-03-05 21:00:00+00:00  1279.0  2021-03-05               24
# 49706 2021-03-05 22:00:00+00:00  1246.0  2021-03-05               24
# 49707 2021-03-05 23:00:00+00:00  1208.0  2021-03-05               24
#
# [47424 rows x 4 columns]

# %%
test_df.shape
# Out:
# (47784, 127)

# %%
test_wdf = test_df.copy()

# %%
test_edf.shape
# Out:
# (49440, 4)

# %%
test_edf.head()
# Out:
#                         DATE  DEMAND   SHORTDATE  RECORDING_COUNT
# 16 2015-07-02 00:00:00+00:00  1282.0  2015-07-02               24
# 17 2015-07-02 01:00:00+00:00  1277.0  2015-07-02               24
# 18 2015-07-02 02:00:00+00:00  1226.0  2015-07-02               24
# 19 2015-07-02 03:00:00+00:00  1186.0  2015-07-02               24
# 20 2015-07-02 04:00:00+00:00  1157.0  2015-07-02               24

# %%
test_edf[test_edf.RECORDING_COUNT != 24]
# Out:
# Empty DataFrame
# Columns: [DATE, DEMAND, SHORTDATE, RECORDING_COUNT]
# Index: []

# %%
test_edf.shape
# Out:
# (49440, 4)

# %%
test_wdf.shape
# Out:
# (47784, 127)

# %%
test_wdf[test_wdf.RECORDING_COUNT != 24]
# Out:
# Empty DataFrame
# Columns: [index, STATION, DATE, REPORT_TYPE, SOURCE, AWND, BackupDirection, BackupDistance, BackupDistanceUnit, BackupElements, BackupElevation, BackupElevationUnit, BackupEquipment, BackupLatitude, BackupLongitude, BackupName, CDSD, CLDD, DSNW, DailyAverageDewPointTemperature, DailyAverageDryBulbTemperature, DailyAverageRelativeHumidity, DailyAverageSeaLevelPressure, DailyAverageStationPressure, DailyAverageWetBulbTemperature, DailyAverageWindSpeed, DailyCoolingDegreeDays, DailyDepartureFromNormalAverageTemperature, DailyHeatingDegreeDays, DailyMaximumDryBulbTemperature, DailyMinimumDryBulbTemperature, DailyPeakWindDirection, DailyPeakWindSpeed, DailyPrecipitation, DailySnowDepth, DailySnowfall, DailySustainedWindDirection, DailySustainedWindSpeed, DailyWeather, HDSD, HTDD, HeavyFog, HourlyAltimeterSetting, HourlyDewPointTemperature, HourlyDryBulbTemperature, HourlyPrecipitation, HourlyPresentWeatherType, HourlyPressureChange, HourlyPressureTendency, HourlyRelativeHumidity, HourlySeaLevelPressure, HourlySkyConditions, HourlyStationPressure, HourlyVisibility, HourlyWetBulbTemperature, HourlyWindDirection, HourlyWindGustSpeed, HourlyWindSpeed, MonthlyAverageRH, MonthlyDaysWithGT001Precip, MonthlyDaysWithGT010Precip, MonthlyDaysWithGT32Temp, MonthlyDaysWithGT90Temp, MonthlyDaysWithLT0Temp, MonthlyDaysWithLT32Temp, MonthlyDepartureFromNormalAverageTemperature, MonthlyDepartureFromNormalCoolingDegreeDays, MonthlyDepartureFromNormalHeatingDegreeDays, MonthlyDepartureFromNormalMaximumTemperature, MonthlyDepartureFromNormalMinimumTemperature, MonthlyDepartureFromNormalPrecipitation, MonthlyDewpointTemperature, MonthlyGreatestPrecip, MonthlyGreatestPrecipDate, MonthlyGreatestSnowDepth, MonthlyGreatestSnowDepthDate, MonthlyGreatestSnowfall, MonthlyGreatestSnowfallDate, MonthlyMaxSeaLevelPressureValue, MonthlyMaxSeaLevelPressureValueDate, MonthlyMaxSeaLevelPressureValueTime, MonthlyMaximumTemperature, MonthlyMeanTemperature, MonthlyMinSeaLevelPressureValue, MonthlyMinSeaLevelPressureValueDate, MonthlyMinSeaLevelPressureValueTime, MonthlyMinimumTemperature, MonthlySeaLevelPressure, MonthlyStationPressure, MonthlyTotalLiquidPrecipitation, MonthlyTotalSnowfall, MonthlyWetBulb, NormalsCoolingDegreeDay, NormalsHeatingDegreeDay, REM, REPORT_TYPE.1, SOURCE.1, ShortDurationEndDate005, ShortDurationEndDate010, ShortDurationEndDate015, ...]
# Index: []
#
# [0 rows x 127 columns]

# %%
edf = test_edf[test_edf.SHORTDATE.isin(match)]

# %%
match = edf.SHORTDATE.unique().tolist()

# %%
wdf = test_wdf[test_wdf.SHORTDATE.isin(match)]

# %%
edf.shape
# Out:
# (47424, 4)

# %%
wdf.shape
# Out:
# (47424, 127)

# %% [markdown]
# ### Now that both weather and electricity dataframes have exactly one recording per hour and 24 recordings per day, we can combine the dataframes into our final df

# %%
wdf['DEMAND'] = edf.DEMAND
# Out:
# <ipython-input-70-f5cfe549c807>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wdf['DEMAND'] = edf.DEMAND

# %%
wdf.drop(columns=['index', 'DEMAND'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-82f1c0816aa9> in <module>
# ----> 1 wdf.drop(columns=['index', 'DEMAND'], inplace=True)
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4303                 weight  1.0     0.8
#    4304         """
# -> 4305         return super().drop(
#    4306             labels=labels,
#    4307             axis=axis,
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['index' 'DEMAND'] not found in axis"

# %%
wdf.reset_index(inplace=True, drop=True)

# %%
edf.reset_index(inplace=True, drop=True)

# %%
wdf.shape[0] == edf.shape[0]
# Out:
# True

# %%
wdf
# Out:
#            STATION                DATE REPORT_TYPE SOURCE  AWND  \
# 0      72793524234 2015-07-02 00:53:00       FM-15      7   NaN
# 1      72793524234 2015-07-02 01:53:00       FM-15      7   NaN
# 2      72793524234 2015-07-02 02:53:00       FM-15      7   NaN
# 3      72793524234 2015-07-02 03:53:00       FM-15      7   NaN
# 4      72793524234 2015-07-02 04:53:00       FM-15      7   NaN
# ...            ...                 ...         ...    ...   ...
# 47419  72793524234 2021-03-05 19:53:00       FM-15      7   NaN
# 47420  72793524234 2021-03-05 20:53:00       FM-15      7   NaN
# 47421  72793524234 2021-03-05 21:53:00       FM-15      7   NaN
# 47422  72793524234 2021-03-05 22:53:00       FM-15      7   NaN
# 47423  72793524234 2021-03-05 23:53:00       FM-15      7   NaN
#
#        BackupDirection  BackupDistance  BackupDistanceUnit  BackupElements  \
# 0                  NaN             NaN                 NaN             NaN
# 1                  NaN             NaN                 NaN             NaN
# 2                  NaN             NaN                 NaN             NaN
# 3                  NaN             NaN                 NaN             NaN
# 4                  NaN             NaN                 NaN             NaN
# ...                ...             ...                 ...             ...
# 47419              NaN             NaN                 NaN             NaN
# 47420              NaN             NaN                 NaN             NaN
# 47421              NaN             NaN                 NaN             NaN
# 47422              NaN             NaN                 NaN             NaN
# 47423              NaN             NaN                 NaN             NaN
#
#        BackupElevation  ...  ShortDurationPrecipitationValue100  \
# 0                  NaN  ...                                 NaN
# 1                  NaN  ...                                 NaN
# 2                  NaN  ...                                 NaN
# 3                  NaN  ...                                 NaN
# 4                  NaN  ...                                 NaN
# ...                ...  ...                                 ...
# 47419              NaN  ...                                 NaN
# 47420              NaN  ...                                 NaN
# 47421              NaN  ...                                 NaN
# 47422              NaN  ...                                 NaN
# 47423              NaN  ...                                 NaN
#
#        ShortDurationPrecipitationValue120  ShortDurationPrecipitationValue150  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
# ...                                   ...                                 ...
# 47419                                 NaN                                 NaN
# 47420                                 NaN                                 NaN
# 47421                                 NaN                                 NaN
# 47422                                 NaN                                 NaN
# 47423                                 NaN                                 NaN
#
#        ShortDurationPrecipitationValue180  Sunrise  Sunset  TStorms  \
# 0                                     NaN      NaN     NaN      NaN
# 1                                     NaN      NaN     NaN      NaN
# 2                                     NaN      NaN     NaN      NaN
# 3                                     NaN      NaN     NaN      NaN
# 4                                     NaN      NaN     NaN      NaN
# ...                                   ...      ...     ...      ...
# 47419                                 NaN      NaN     NaN      NaN
# 47420                                 NaN      NaN     NaN      NaN
# 47421                                 NaN      NaN     NaN      NaN
# 47422                                 NaN      NaN     NaN      NaN
# 47423                                 NaN      NaN     NaN      NaN
#
#        WindEquipmentChangeDate   SHORTDATE RECORDING_COUNT
# 0                   2007-05-17  2015-07-02              24
# 1                   2007-05-17  2015-07-02              24
# 2                   2007-05-17  2015-07-02              24
# 3                   2007-05-17  2015-07-02              24
# 4                   2007-05-17  2015-07-02              24
# ...                        ...         ...             ...
# 47419               2007-05-17  2021-03-05              24
# 47420               2007-05-17  2021-03-05              24
# 47421               2007-05-17  2021-03-05              24
# 47422               2007-05-17  2021-03-05              24
# 47423               2007-05-17  2021-03-05              24
#
# [47424 rows x 126 columns]

# %%
wdf['DEMAND'] = edf.DEMAND.copy()
# Out:
# <ipython-input-84-bffacd6e4e7d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wdf['DEMAND'] = edf.DEMAND.copy()

# %%
wdf
# Out:
#            STATION                DATE REPORT_TYPE SOURCE  AWND  \
# 0      72793524234 2015-07-02 00:53:00       FM-15      7   NaN
# 1      72793524234 2015-07-02 01:53:00       FM-15      7   NaN
# 2      72793524234 2015-07-02 02:53:00       FM-15      7   NaN
# 3      72793524234 2015-07-02 03:53:00       FM-15      7   NaN
# 4      72793524234 2015-07-02 04:53:00       FM-15      7   NaN
# ...            ...                 ...         ...    ...   ...
# 47419  72793524234 2021-03-05 19:53:00       FM-15      7   NaN
# 47420  72793524234 2021-03-05 20:53:00       FM-15      7   NaN
# 47421  72793524234 2021-03-05 21:53:00       FM-15      7   NaN
# 47422  72793524234 2021-03-05 22:53:00       FM-15      7   NaN
# 47423  72793524234 2021-03-05 23:53:00       FM-15      7   NaN
#
#        BackupDirection  BackupDistance  BackupDistanceUnit  BackupElements  \
# 0                  NaN             NaN                 NaN             NaN
# 1                  NaN             NaN                 NaN             NaN
# 2                  NaN             NaN                 NaN             NaN
# 3                  NaN             NaN                 NaN             NaN
# 4                  NaN             NaN                 NaN             NaN
# ...                ...             ...                 ...             ...
# 47419              NaN             NaN                 NaN             NaN
# 47420              NaN             NaN                 NaN             NaN
# 47421              NaN             NaN                 NaN             NaN
# 47422              NaN             NaN                 NaN             NaN
# 47423              NaN             NaN                 NaN             NaN
#
#        BackupElevation  ...  ShortDurationPrecipitationValue120  \
# 0                  NaN  ...                                 NaN
# 1                  NaN  ...                                 NaN
# 2                  NaN  ...                                 NaN
# 3                  NaN  ...                                 NaN
# 4                  NaN  ...                                 NaN
# ...                ...  ...                                 ...
# 47419              NaN  ...                                 NaN
# 47420              NaN  ...                                 NaN
# 47421              NaN  ...                                 NaN
# 47422              NaN  ...                                 NaN
# 47423              NaN  ...                                 NaN
#
#        ShortDurationPrecipitationValue150  ShortDurationPrecipitationValue180  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
# ...                                   ...                                 ...
# 47419                                 NaN                                 NaN
# 47420                                 NaN                                 NaN
# 47421                                 NaN                                 NaN
# 47422                                 NaN                                 NaN
# 47423                                 NaN                                 NaN
#
#        Sunrise  Sunset  TStorms  WindEquipmentChangeDate   SHORTDATE  \
# 0          NaN     NaN      NaN               2007-05-17  2015-07-02
# 1          NaN     NaN      NaN               2007-05-17  2015-07-02
# 2          NaN     NaN      NaN               2007-05-17  2015-07-02
# 3          NaN     NaN      NaN               2007-05-17  2015-07-02
# 4          NaN     NaN      NaN               2007-05-17  2015-07-02
# ...        ...     ...      ...                      ...         ...
# 47419      NaN     NaN      NaN               2007-05-17  2021-03-05
# 47420      NaN     NaN      NaN               2007-05-17  2021-03-05
# 47421      NaN     NaN      NaN               2007-05-17  2021-03-05
# 47422      NaN     NaN      NaN               2007-05-17  2021-03-05
# 47423      NaN     NaN      NaN               2007-05-17  2021-03-05
#
#        RECORDING_COUNT  DEMAND
# 0                   24  1282.0
# 1                   24  1277.0
# 2                   24  1226.0
# 3                   24  1186.0
# 4                   24  1157.0
# ...                ...     ...
# 47419               24  1276.0
# 47420               24  1291.0
# 47421               24  1279.0
# 47422               24  1246.0
# 47423               24  1208.0
#
# [47424 rows x 127 columns]

# %%
with open('seattle_data.pkl', 'wb') as picklefile:
    pickle.dump(wdf, picklefile)
